# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

import itertools
import seaborn as sns

# %load_ext autoreload
# %autoreload 2

# %%
from literal_listener import StatelessLiteralListener
from literal_speaker import LiteralSpeaker
from pragmatic_listener import PragmaticListener
from learner import LearnerAgent

from configuration import TRUE_REWARDS

from visualizations import visualize_pragmatic_beliefs, plot_point_estimate

# %% [markdown]
# # Cache Pragmatic Results

# %%
import json
import time

human_utterances = json.load(open("data/linear_data_for_agents.json"))

# %% [markdown]
# ## Pragmatic - Uncertain

# %%
n_trials = 25
alphaS = 3
n_iters = 5

utterances_to_use = human_utterances
prior_var = 5
importance_samples = 100
unique_str="-v4-ER"


exp_literal = StatelessLiteralListener()
exp_speaker = LiteralSpeaker(exp_literal, utterances="exp", alphaS=alphaS)
exp_pragmatic_listener = PragmaticListener(exp_speaker)

start_time_ms = round(time.time() * 1000)   

for i, u in enumerate(utterances_to_use):

    pragmatic = LearnerAgent.cache_pragmatic_thompson_sampling(exp_pragmatic_listener, u["utt"], u["action_context"], 
                                                               horizons=[1,2,4], workerid=u['workerid'],
                                                               n_trials=n_trials, prior_var=prior_var, 
                                                               min_importance_samples=importance_samples, 
                                                               n_iterations=n_iters, verbose=False,
                                                               unique_str=unique_str)

    if i%500 == 0:
        end_time_ms = round(time.time() * 1000)
        n_seconds = (end_time_ms - start_time_ms) / 1000
        print(f'Finished utterance {i} of {len(utterances_to_use)}, took {n_seconds} seconds.')
        start_time_ms = end_time_ms
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\Python-Analysis\pragmatic_listener.py:34, in PragmaticListener.single_horizon_inference(self, utt, context, horizon)
#      33 try:
# ---> 34     df = pd.read_parquet(file_path)
#      35 except FileNotFoundError:
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\.venv\lib\site-packages\pandas\io\parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
#     674     use_nullable_dtypes=use_nullable_dtypes,
#     675     dtype_backend=dtype_backend,
#     676     filesystem=filesystem,
#     677     **kwargs,
#     678 )
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\.venv\lib\site-packages\pandas\io\parquet.py:258, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     257     to_pandas_kwargs["split_blocks"] = True
# --> 258 path_or_handle, handles, filesystem = _get_path_or_handle(
#     259     path,
#     260     filesystem,
#     261     storage_options=storage_options,
#     262     mode="rb",
#     263 )
#     264 try:
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\.venv\lib\site-packages\pandas\io\parquet.py:141, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     132 if (
#     133     not fs
#     134     and not is_dir
#    (...)
#     139     # fsspec resources can also point to directories
#     140     # this branch is used for example when reading from non-fsspec URLs
# --> 141     handles = get_handle(
#     142         path_or_handle, mode, is_text=False, storage_options=storage_options
#     143     )
#     144     fs = None
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\.venv\lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880 else:
#     881     # Binary mode
# --> 882     handle = open(handle, ioargs.mode)
#     883 handles.append(handle)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/cached_inference/H-1-C-color-blue-shape-circle-color-green-shape-triangle-color-red-shape-circle-U-type-description-feature-green-value-2-utt-exp-alphaS-3-alphaL-3.parquet'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 19
#      15 start_time_ms = round(time.time() * 1000)
#      17 for i, u in enumerate(utterances_to_use):
# ---> 19     pragmatic = LearnerAgent.cache_pragmatic_thompson_sampling(exp_pragmatic_listener, u["utt"], u["action_context"],
#      20                                                                horizons=[1,2,4], workerid=u['workerid'],
#      21                                                                n_trials=n_trials, prior_var=prior_var,
#      22                                                                min_importance_samples=importance_samples,
#      23                                                                n_iterations=n_iters, verbose=False,
#      24                                                                unique_str=unique_str)
#      26     if i%500 == 0:
#      27         end_time_ms = round(time.time() * 1000)
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\Python-Analysis\learner.py:223, in LearnerAgent.cache_pragmatic_thompson_sampling(cls, pragmatic_listener, utterance, state, horizons, prior_var, workerid, min_importance_samples, n_trials, n_iterations, verbose, unique_str)
#     220     print(f'\tRetrieved {previous_iterations} previous TS simulations (looking for {n_iterations}).')
#     222 # Generate a posterior, then marginalize over horizon to get the probability of different reward weights.
# --> 223 posterior = pragmatic_listener.inference(utterance, state, horizon=horizons)
#     225 results = []
#     226 start_time_ms = round(time.time() * 1000)
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\Python-Analysis\pragmatic_listener.py:23, in PragmaticListener.inference(self, utt, context, horizon)
#      20 def inference(self, utt, context, horizon):
#      22     if isinstance(horizon, list):
# ---> 23         return self.multihorizon_inference(utt, context, horizon)
#      24     else:
#      25         return self.single_horizon_inference(utt, context, horizon)
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\Python-Analysis\pragmatic_listener.py:47, in PragmaticListener.multihorizon_inference(self, utt, context, horizons)
#      45 horizon_posteriors = []
#      46 for h in horizons:
# ---> 47     single_horizon_posterior = self.single_horizon_inference(utt, context, h)
#      48     single_horizon_posterior['horizon'] = h
#      49     horizon_posteriors.append(single_horizon_posterior)
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\Python-Analysis\pragmatic_listener.py:36, in PragmaticListener.single_horizon_inference(self, utt, context, horizon)
#      34     df = pd.read_parquet(file_path)
#      35 except FileNotFoundError:
# ---> 36     df = self._regenerate_posterior_beliefs_from_utterance(utt, context, horizon)
#      37     df.to_parquet(file_path)
#      39 normalizing_constant = df.likelihoods.sum()
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\Python-Analysis\pragmatic_listener.py:61, in PragmaticListener._regenerate_posterior_beliefs_from_utterance(self, utt, context, horizon)
#      58 def _regenerate_posterior_beliefs_from_utterance(self, utt, context, horizon):
#      59     """Given a context/utterance, return distribution over rewards."""
# ---> 61     likelihoods = [self.speaker.single_utterance_probability(utt, context, horizon=horizon, reward_weights=w)
#      62                    for w in self.possible_rewards]
#      64     df = pd.DataFrame.from_records(self.possible_rewards)
#      65     df["likelihoods"] = likelihoods
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\Python-Analysis\pragmatic_listener.py:61, in <listcomp>(.0)
#      58 def _regenerate_posterior_beliefs_from_utterance(self, utt, context, horizon):
#      59     """Given a context/utterance, return distribution over rewards."""
# ---> 61     likelihoods = [self.speaker.single_utterance_probability(utt, context, horizon=horizon, reward_weights=w)
#      62                    for w in self.possible_rewards]
#      64     df = pd.DataFrame.from_records(self.possible_rewards)
#      65     df["likelihoods"] = likelihoods
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\Python-Analysis\literal_speaker.py:59, in LiteralSpeaker.single_utterance_probability(self, utt, context, horizon, reward_weights)
#      55 def single_utterance_probability(self, utt, context, horizon=1, reward_weights=None):
#      57     utterances = UTTERANCES[self.utterances]
# ---> 59     probabilities = self.all_utterance_probabilities(context, horizon=horizon, reward_weights=reward_weights)
#      61     return probabilities[utterances.index(utt)]
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\Python-Analysis\literal_speaker.py:46, in LiteralSpeaker.all_utterance_probabilities(self, context, horizon, reward_weights)
#      43     reward_weights = self.reward_weights
#      45 truth_rewards = [self.truth_value(utt, reward_weights) for utt in utterances]
# ---> 46 present_rewards = [self.listener.present_rewards(utt, context, reward_weights) for utt in utterances]
#      47 future_rewards = [self.listener.future_rewards(utt, context, reward_weights) for utt in utterances]
#      49 utterance_rewards = [t + (p + (horizon - 1) * f)/horizon for t, p, f in zip(truth_rewards,
#      50                                                                             present_rewards,
#      51                                                                             future_rewards)]
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\Python-Analysis\literal_speaker.py:46, in <listcomp>(.0)
#      43     reward_weights = self.reward_weights
#      45 truth_rewards = [self.truth_value(utt, reward_weights) for utt in utterances]
# ---> 46 present_rewards = [self.listener.present_rewards(utt, context, reward_weights) for utt in utterances]
#      47 future_rewards = [self.listener.future_rewards(utt, context, reward_weights) for utt in utterances]
#      49 utterance_rewards = [t + (p + (horizon - 1) * f)/horizon for t, p, f in zip(truth_rewards,
#      50                                                                             present_rewards,
#      51                                                                             future_rewards)]
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\Python-Analysis\literal_listener.py:85, in StatelessLiteralListener.present_rewards(self, utt, context, rewards)
#      82 def present_rewards(self, utt, context, rewards):
#      83     """Main entry point for evaluating utterances in context-- auto-caches results."""
# ---> 85     features = self.present_feature_counts(utt, context)
#      86     return self.feature_count_rewards(features, rewards)
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\Python-Analysis\literal_listener.py:53, in StatelessLiteralListener.present_feature_counts(self, utt, context, alphaL)
#      51     probabilities = [self._prob_action_from_instruction(a, context, utt) for a in context]
#      52 else:
# ---> 53     probabilities = [self._prob_action_from_description(a, context, utt, alphaL=alphaL) for a in context]
#      55 for a, prob in zip(context, probabilities):
#      56     feature_counts[a["color"]] += prob
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\Python-Analysis\literal_listener.py:53, in <listcomp>(.0)
#      51     probabilities = [self._prob_action_from_instruction(a, context, utt) for a in context]
#      52 else:
# ---> 53     probabilities = [self._prob_action_from_description(a, context, utt, alphaL=alphaL) for a in context]
#      55 for a, prob in zip(context, probabilities):
#      56     feature_counts[a["color"]] += prob
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\Python-Analysis\literal_listener.py:37, in StatelessLiteralListener._prob_action_from_description(self, action, context, description, alphaL)
#      34 beliefs = {k: 0 for k in SHAPES + COLORS}
#      35 beliefs[description['feature']] = description['value']
# ---> 37 return self.prob_action_from_beliefs(action, context, beliefs, alphaL=alphaL)
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\Python-Analysis\base_listener.py:38, in BaseListener.prob_action_from_beliefs(self, action, context, beliefs, alphaL)
#      35 if alphaL is None:
#      36     alphaL = self.alphaL
# ---> 38 this_logit = action_rewards_from_beliefs(action, beliefs) * alphaL
#      39 other_rewards = [action_rewards_from_beliefs(a, beliefs) * alphaL for a in context]
#      41 # Need to worry about underflow, but contexts are only 3 items so probably not a concern in practice
#
# File c:\Users\kylee\OneDrive\Documents\GitHub\How_To_Talk\Python-Analysis\configuration.py:45, in action_rewards_from_beliefs(action, beliefs)
#      44 def action_rewards_from_beliefs(action, beliefs):
# ---> 45     return beliefs[action["color"]] + beliefs[action["shape"]]
#
# KeyError: 'circle'

# %% [markdown]
# ## Pragmatic - Misaligned

# %%
start_time_ms = round(time.time() * 1000)   

for i, u in enumerate(utterances_to_use):

    pragmatic = LearnerAgent.cache_pragmatic_thompson_sampling(exp_pragmatic_listener,
                                                               u["utt"], u["action_context"], 
                                                               workerid=u['workerid'], unique_str=unique_str, 
                                                               prior_var=prior_var, min_importance_samples=importance_samples,
                                                               n_iterations=n_iters, n_trials=n_trials, verbose=False,
                                                               horizons=[1]) # This changes

    if i%500 == 0:
        end_time_ms = round(time.time() * 1000)
        n_seconds = (end_time_ms - start_time_ms) / 1000
        print(f'Finished utterance {i} of {len(utterances_to_use)}, took {n_seconds} seconds.')
        start_time_ms = end_time_ms

# %%
start_time_ms = round(time.time() * 1000)   

for i, u in enumerate(utterances_to_use):

    pragmatic = LearnerAgent.cache_pragmatic_thompson_sampling(exp_pragmatic_listener,
                                                               u["utt"], u["action_context"], 
                                                               workerid=u['workerid'], unique_str=unique_str, 
                                                               prior_var=prior_var, min_importance_samples=importance_samples,
                                                               n_iterations=n_iters, n_trials=n_trials, verbose=False,
                                                               horizons=[4]) # This changes

    if i%500 == 0:
        end_time_ms = round(time.time() * 1000)
        n_seconds = (end_time_ms - start_time_ms) / 1000
        print(f'Finished utterance {i} of {len(utterances_to_use)}, took {n_seconds} seconds.')
        start_time_ms = end_time_ms

# %% [markdown]
# ## Pragmatic - Known

# %%
start_time_ms = round(time.time() * 1000)   

for i, u in enumerate(utterances_to_use):
    
    pragmatic = LearnerAgent.cache_pragmatic_thompson_sampling(exp_pragmatic_listener,
                                                               u["utt"], u["action_context"], 
                                                               workerid=u['workerid'], unique_str=unique_str, 
                                                               prior_var=prior_var, min_importance_samples=importance_samples,
                                                               n_iterations=n_iters, n_trials=n_trials, verbose=False,
                                                               horizons=[u["horizon"]]) # This changes

    if i%500 == 0:
        end_time_ms = round(time.time() * 1000)
        n_seconds = (end_time_ms - start_time_ms) / 1000
        print(f'Finished utterance {i} of {len(utterances_to_use)}, took {n_seconds} seconds.')
        start_time_ms = end_time_ms

# %% [markdown]
# # Load cached results

# %%
from configuration import utt_to_string

results = []

pragmatics_list = ["pragmatic_uncertain", 
                   "pragmatic_misaligned_conservative", 
                   "pragmatic_misaligned_pedagogic", 
                   "pragmatic_aligned"]

for i, u in enumerate(utterances_to_use):
    
    for pragmatics in pragmatics_list:
        
        if pragmatics == "pragmatic_uncertain":
            horizons = [1, 2, 4]
        elif pragmatics == "pragmatic_aligned":
            horizons = [u["horizon"]]
        elif pragmatics == "pragmatic_misaligned_conservative":
            horizons = [1]
        elif pragmatics == "pragmatic_misaligned_pedagogic":
            horizons = [4]
        
        pragmatic = LearnerAgent.cache_pragmatic_thompson_sampling(exp_pragmatic_listener,
                                                                   u["utt"], u["action_context"], 
                                                                   workerid=u['workerid'], unique_str=unique_str, 
                                                                   prior_var=prior_var, min_importance_samples=importance_samples,
                                                                   n_iterations=n_iters, n_trials=n_trials,
                                                                   horizons=horizons) # This changes
        pragmatic["listener"] = pragmatics

        pragmatic["alphaS"] = alphaS
        pragmatic["horizon"] = u["horizon"]

        for k in ["color", "shape", "feature", "value", "type"]:
            pragmatic[k] = u["utt"].get(k)

        utt_str = utt_to_string(u["utt"])
        pragmatic["utt"] = utt_str
        pragmatic["utt_key"] = f'{u["action_context"]}-{utt_str}'

        pragmatic["trial_iteration_key"] = pragmatic["iteration"].apply(lambda x: f'{u["action_context"]}-{u["workerid"]}-{x}')

        pragmatic["random_effects_key"] = f'{u["action_context"]}-{u["workerid"]}'
        results.append(pragmatic)

# %% [markdown]
# ## Literal

# %%
for i, u in enumerate(utterances_to_use):
    
    random_effects_key = f'{u["action_context"]}-{u["workerid"]}'
        
    literal = LearnerAgent.cache_literal_thompson_sampling(u["utt"], unique_str=random_effects_key,
                                                           n_iterations=n_iters, 
                                                           n_trials=n_trials, 
                                                           prior_var=prior_var,
                                                           min_importance_samples=importance_samples,
                                                           verbose=False)
    
    literal["listener"] = "literal"
    literal["utt"] = utt_str

    for k in ["color", "shape", "feature", "value", "type"]:
        literal[k] = u.get(k)
        
    literal["trial_iteration_key"] = literal["iteration"].apply(lambda x: f'{u}-{x}')
    literal['random_effects_key'] = random_effects_key
    results.append(literal)  
    
    if i%500 == 0:
        print(f'Finished {n_iters} iters on utterance {i}.')

# %% [markdown]
# ## Individual Baseline

# %%
for i, u in enumerate(utterances_to_use):
    
    random_effects_key = f'{u["action_context"]}-{u["workerid"]}'
    
    individual_learning_results = LearnerAgent.cache_individual_thompson_sampling(n_iterations=n_iters,  
                                                                                  n_trials=n_trials, 
                                                                                  prior_var=prior_var, 
                                                                                  unique_str=random_effects_key)
    
    individual_learning_results["listener"] = "individual"
        
    individual_learning_results["trial_iteration_key"] = literal["iteration"].apply(lambda x: f'{u}-{x}')
    individual_learning_results['random_effects_key'] = random_effects_key
    results.append(individual_learning_results)  
    
    if i%500 == 0:
        print(f'Finished {n_iters} iters on utterance {i}.')

# %% [markdown]
# ## Plot Results

# %%
results = pd.concat(results)
results["horizon"] = results.horizon.fillna("N/A")

# %%
# Should have 2772 * 5 trials for each listener
results.groupby(["listener"]).trial_iteration_key.nunique() / 5

# %%
import copy 

to_plot = copy.deepcopy(results)

# %%
rename_dict = {"pragmatic_uncertain": "Pragmatic - Latent $H$", "literal": "Literal Listener", "individual": "Individual Learner"}
to_plot = to_plot[to_plot.listener.isin(list(rename_dict.keys()))]

to_plot["listener"] = to_plot.listener.apply(lambda x: rename_dict.get(x, x))
hue_order = ["Pragmatic - Latent $H$", "Literal Listener", "Individual Learner"]
palette = ['green', 'black', 'gray']

# %%
sns.lineplot(data=to_plot, x='trial', y='future_rewards', hue='listener', hue_order=hue_order, palette=palette,
             linewidth=3, alpha=.6)

plt.ylim(.75, 1.8) 
plt.axhline(1.75, c='k', label="Optimal", linestyle='--', linewidth=3, alpha=.6)
plt.legend(loc='best', fontsize=15)

ys = [1, 1.25, 1.5, 1.75]
for y in ys:
    plt.axhline(y, c='k', alpha=.2, linestyle='--', zorder=0)

plt.yticks(ys, fontsize=15)
plt.ylabel("Future Rewards", fontsize=20)
plt.xticks([1, 5, 10, 15, 20, 25], fontsize=15)
plt.xlim(1, 25);
plt.xlabel("Individual Learning Actions", fontsize=20)

# plt.xlim(.5, 15)

# %%
sns.lineplot(data=to_plot, x='trial', y='regret', hue='listener', hue_order=hue_order, palette=palette)

ys=[0, .25, .5, .75, 1, 1.25, 1.5, 1.75]
plt.yticks(ys, fontsize=15)
for y in ys:
    plt.axhline(y, c='k', alpha=.2, linestyle='--', zorder=0)

plt.ylabel("Regret", fontsize=20)
plt.xticks([1, 5, 10, 15, 20, 25], fontsize=15)
plt.xlim(1, 25);
plt.xlabel("Individual Learning Actions", fontsize=20)
plt.legend(fontsize=18)

# %% [markdown]
# ## Summarize Results

# %%
results_to_summarize = results

# %% [markdown]
# ### Regret @ 25

# %%
regret_totals = results_to_summarize.groupby(["listener", "trial_iteration_key"])["regret"].sum().reset_index()

# %%
regret_totals.groupby("listener").regret.agg(np.mean).round(2)

# %%
### Export to R
for_r = results_to_summarize.groupby(["listener", "trial_iteration_key", "random_effects_key"]).regret.sum().reset_index()
for_r["centered_regret"] = for_r.regret - for_r.regret.mean()

for_r

# %%
for_r.to_csv("regret_results_for_r.csv", index=False)

# %% [markdown]
# # Simulation Details

# %% [markdown]
# ## Gaussian Prior
# How wide should initial variance be?
#
# First, we want this to be large in order to approximate a uniform on the interval [-2, 2]
# However, for importance-sampling we need to sample from it and stay within the (-2.5, 2.5) range.
#
# With variance=5 and 6 dimensions, we should get 66% of samples within (-2.5, 2.5) which means .66^6 ~~ 8% of our initial samples will be accepted.

# %%
from scipy.stats import norm
import math

variance = 5

interval = norm.interval(.66, loc=0, scale=math.sqrt(variance))
acceptance = .66**6

print(f'Interval of {interval} --> acceptance of {acceptance}.')
